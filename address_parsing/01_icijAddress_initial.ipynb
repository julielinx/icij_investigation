# %% [markdown]
# # NLP 05: The importance of deduplication
#
# Real world free text is messy. Free text is basically giving every data entry contributor permission to give you a unique snowflake amalgamation of words, spelled in whatever way just happens to come out. Once that data is collected, it then has to be turned into something relevant.
#
# A large part of this is ensuring that each row only represents one "thing." When trying to determine how much you have of something, like apples, it doesn't do any good to count the same one over and over again. The same is true of datasets, large and small. If the same item is represented multiple times it will create problems in the analysis and make any insights much less insightful.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
import re
from time import gmtime, strftime
import sys
import os
import io

import zipfile

# %%
with zipfile.ZipFile("../aws/data/full-oldb.20220708.zip", 'r') as zip_ref:
    zip_ref.extractall("data/original")
    
df = pd.read_csv('data/original/nodes-addresses.csv')
# Out:
# C:\Users\jfish\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (2,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# The datasets housed by the [International Consortium of Investigative Journalists](https://www.icij.org/), such as the Panama Papers, include some excellent examples of such real world free text data. In particular, the addresses in the [Offshore Leaks dataset](https://offshoreleaks.icij.org/) are particularly good. The initial dataset has 402,246 rows and 225 country codes. However, there are 365 countries, so there's something fishy in this dataset.

# %%
print('Number of rows in the dataset:',df.shape[0])
print(f'Number of country codes in the dataset: {df.country_codes.nunique()}')
print('Number of countries in the dataset: {}'.format(df.countries.nunique()))
# Out:
# Number of rows in the dataset: 402246
# Number of country codes in the dataset: 225
# Number of countries in the dataset: 365

# %% [markdown]
# I don't have to dig much deeper to find more inconsistencies. Using `pandas` built in duplicate finder, I can see not only that there are duplicate addresses, but there are addresses in the `name` column, the use of punctuation is all over the place, and there is no standardization in the format of the address.
#
# The duplicate entries for "1 Cabot Square" are a good example:
#
# - "1 Cabot Square; London E14 4QJ; United Kingdom"
# - 1 Cabot Square; London; United Kingdom E14 4QR
#
# In not being from the UK, it's impossible for me to tell if the "E14" portion of the address is a street number, apartment/flat number, or some kind of postal code.
#
# In order to analyze this data and get meaningful results, this data needs to be cleaned and standardized. Most importantly, the same address needs to point to a single observation (i.e.: one row per address).

# %%
pd.set_option('display.max_colwidth', 1000)

# %%
df[df.address.duplicated(keep=False)].sort_values('address').head(31)
# Out:
#           node_id                                        address  \
# 209760   81013976                                     "Chequers"
# 155649   81021301                                     "Chequers"
# 175526   81047974                                     "Seascape"
# 173661   81045646                                     "Seascape"
# 158234   81026137            #05-06, Pan Pacific Serviced Suites
# 166520   81036861            #05-06, Pan Pacific Serviced Suites
# 202791   81084819                #19-01 Ardmore II, Ardmore Park
# 202790   81084818                #19-01 Ardmore II, Ardmore Park
# 86870    14086865                                              -
# 207173   81009999                                              -
# 176867   81049651                                              .
# 200845   81082162                                              .
# 89482    14089477                                              .
# 253311  240071430  1 AVENIDA 6-27 A, ZONA 14 GUATEMALA GUATEMALA
# 263757  240000894  1 AVENIDA 6-27 A, ZONA 14 GUATEMALA GUATEMALA
# 252966  240071102     1 AVENIDA 6-27 ZONA 14 GUATEMALA GUATEMALA
# 262847  240001416     1 AVENIDA 6-27 ZONA 14 GUATEMALA GUATEMALA
# 159241   81027717                         1 Adelaide Street East
# 200132   81081167                         1 Adelaide Street East
# 159730   81028787                         1 Adelaide Street East
# 204891   81001139                                 1 Athol Street
# 198978   81079613                                 1 Athol Street
# 189122   81064990                    1 Avenue de Grande Bretagne
# 184043   81058582                    1 Avenue de Grande Bretagne
# 152527   81015674                    1 Avenue de Grande Bretagne
# 155280   81020579                              1 Berkeley Street
# 176350   81049010                              1 Berkeley Street
# 166859   81037290                                  1 Bryant Park
# 184382   81058994                                  1 Bryant Park
# 209572   81013630                                 1 Cabot Square
# 205436   81002016                                 1 Cabot Square
#
#                                                                            name  \
# 209760       "Chequers"; 1741, Tiki Tiki Road, RD 1; Te Kuiti 3981; New Zealand
# 155649                  "Chequers"; Tiki Tiki Road; R.D.1 Te Kuiti; New Zealand
# 175526               "Seascape" ; 27 Devon Point Lane; Devonshire FL05; Bermuda
# 173661                     "Seascape"; 20 Grape Bay Drive; Paget PG 06; Bermuda
# 158234  #05-06, Pan Pacific Serviced Suites; 96 Somerset Road; Singapore 238163
# 166520  #05-06, Pan Pacific Serviced Suites; 96 Somerset Road; Singapore 238163
# 202791                       #19-01 Ardmore II, Ardmore Park; 259947; Singapore
# 202790                       #19-01 Ardmore II, Ardmore Park; 259947; Singapore
# 86870                                                                       NaN
# 207173                                                                  -; NONE
# 176867                                                             .; Hong Kong
# 200845                                           .; PO BOX 2677 Manama; Bahrain
# 89482                                                                       NaN
# 253311                                                                      NaN
# 263757                                                                      NaN
# 252966                                                                      NaN
# 262847                                                                      NaN
# 159241    1 Adelaide Street East; Suite 2100; Toronto, ONtario  M5C 2V9; Canada
# 200132                 1 Adelaide Street East; Toronto M5C 2V9; Ontario; Canada
# 159730     1 Adelaide Street East; Suite 200; Toronto, ONtario  M5C 2V9; Canada
# 204891                             1 Athol Street; Douglas; Isle of Man IM1 1LD
# 198978                                     1 Athol Street; Douglas; Isle of Man
# 189122          1 Avenue de Grande Bretagne; "Les Floralies"; MC  98000; Monaco
# 184043                1 Avenue de Grande Bretagne; Monte Carlo MC 98000; Monaco
# 152527                 1 Avenue de Grande Bretagne; MC98000 Monte-Carlo; Monaco
# 155280               1 Berkeley Street; W1J 8DJ London; England; United Kingdom
# 176350                               1 Berkeley Street; W1J 8DJ; United Kingdom
# 166859              1 Bryant Park; New York NY  10036; United States of America
# 184382              1 Bryant Park; New York NY  07093; United States of America
# 209572                           1 Cabot Square; London E14 4QJ; United Kingdom
# 205436                           1 Cabot Square; London; United Kingdom E14 4QR
#
#              countries country_codes  \
# 209760     New Zealand           NZL
# 155649     New Zealand           NZL
# 175526         Bermuda           BMU
# 173661         Bermuda           BMU
# 158234       Singapore           SGP
# 166520       Singapore           SGP
# 202791       Singapore           SGP
# 202790       Singapore           SGP
# 86870              NaN           NaN
# 207173             NaN           NaN
# 176867       Hong Kong           HKG
# 200845         Bahrain           BHR
# 89482              NaN           NaN
# 253311       Guatemala           GTM
# 263757       Guatemala           GTM
# 252966       Guatemala           GTM
# 262847       Guatemala           GTM
# 159241          Canada           CAN
# 200132          Canada           CAN
# 159730          Canada           CAN
# 204891     Isle of Man           IMN
# 198978     Isle of Man           IMN
# 189122          Monaco           MCO
# 184043          Monaco           MCO
# 152527          Monaco           MCO
# 155280  United Kingdom           GBR
# 176350  United Kingdom           GBR
# 166859   United States           USA
# 184382   United States           USA
# 209572  United Kingdom           GBR
# 205436  United Kingdom           GBR
#
#                                                          sourceID  \
# 209760                                  Paradise Papers - Appleby
# 155649                                  Paradise Papers - Appleby
# 175526                                  Paradise Papers - Appleby
# 173661                                  Paradise Papers - Appleby
# 158234                                  Paradise Papers - Appleby
# 166520                                  Paradise Papers - Appleby
# 202791                                  Paradise Papers - Appleby
# 202790                                  Paradise Papers - Appleby
# 86870                                               Panama Papers
# 207173                                  Paradise Papers - Appleby
# 176867                                  Paradise Papers - Appleby
# 200845                                  Paradise Papers - Appleby
# 89482                                               Panama Papers
# 253311  Pandora Papers - Alemán, Cordero, Galindo & Lee (Alcogal)
# 263757  Pandora Papers - Alemán, Cordero, Galindo & Lee (Alcogal)
# 252966  Pandora Papers - Alemán, Cordero, Galindo & Lee (Alcogal)
# 262847  Pandora Papers - Alemán, Cordero, Galindo & Lee (Alcogal)
# 159241                                  Paradise Papers - Appleby
# 200132                                  Paradise Papers - Appleby
# 159730                                  Paradise Papers - Appleby
# 204891                                  Paradise Papers - Appleby
# 198978                                  Paradise Papers - Appleby
# 189122                                  Paradise Papers - Appleby
# 184043                                  Paradise Papers - Appleby
# 152527                                  Paradise Papers - Appleby
# 155280                                  Paradise Papers - Appleby
# 176350                                  Paradise Papers - Appleby
# 166859                                  Paradise Papers - Appleby
# 184382                                  Paradise Papers - Appleby
# 209572                                  Paradise Papers - Appleby
# 205436                                  Paradise Papers - Appleby
#
#                                             valid_until note
# 209760             Appleby data is current through 2014  NaN
# 155649             Appleby data is current through 2014  NaN
# 175526             Appleby data is current through 2014  NaN
# 173661             Appleby data is current through 2014  NaN
# 158234             Appleby data is current through 2014  NaN
# 166520             Appleby data is current through 2014  NaN
# 202791             Appleby data is current through 2014  NaN
# 202790             Appleby data is current through 2014  NaN
# 86870   The Panama Papers  data is current through 2015  NaN
# 207173             Appleby data is current through 2014  NaN
# 176867             Appleby data is current through 2014  NaN
# 200845             Appleby data is current through 2014  NaN
# 89482   The Panama Papers  data is current through 2015  NaN
# 253311            Provider data is current through 2018  NaN
# 263757            Provider data is current through 2018  NaN
# 252966            Provider data is current through 2018  NaN
# 262847            Provider data is current through 2017  NaN
# 159241             Appleby data is current through 2014  NaN
# 200132             Appleby data is current through 2014  NaN
# 159730             Appleby data is current through 2014  NaN
# 204891             Appleby data is current through 2014  NaN
# 198978             Appleby data is current through 2014  NaN
# 189122             Appleby data is current through 2014  NaN
# 184043             Appleby data is current through 2014  NaN
# 152527             Appleby data is current through 2014  NaN
# 155280             Appleby data is current through 2014  NaN
# 176350             Appleby data is current through 2014  NaN
# 166859             Appleby data is current through 2014  NaN
# 184382             Appleby data is current through 2014  NaN
# 209572             Appleby data is current through 2014  NaN
# 205436             Appleby data is current through 2014  NaN

# %% [markdown]
# ## Standardizations
#
# To be honest, the amount of cleaning the `address` column needs is a little overwhelming. I assumed this had to be a solved problem, what with the international mail system and all. However, I couldn't find a solution that would be able to process the addresses from all the different countries represented in this dataset. There are some solutions for US addresses that I may apply to just that country, but for the most part I'll need to write code for my purposes. The best solution I could find for this problem is to parse the data into more manageble and meaningful chunks.
#
# To get started, I literally went through by hand and did some editing. This was obviously too tedious to keep my attention for long (I got through the country, islands, and cities of the Bahamas). While not sustainable for all 400,000+ rows, it did give me an initial feel for the data.
#
# This manual parsing revealed two large tasks that need to be complete on the full dataset regardless of country:
#
# - Ensure full addresses are in the `address` column
# - Some `country_codes` have slipped into the `countries` column

# %% [markdown]
# ## Move full addresses in the `name` column to the `address` column
#
# A quick sanity check shows that I can just look for rows where the `name` column is longer than the `address` column. It is possible that some company or person has a very long name and short address. This doesn't appear to be the case in this dataset though, thank goodness.

# %%
df.loc[df['name'].str.len() > df['address'].str.len(), ['address', 'name']]
# Out:
#                                    address  \
# 528                        6B Chenyu Court
# 529           15C Suchun Industrial Square
# 151607                         8F., No. 68
# 151608                      No. 66, Ln. 20
# 151609                1F., No. 18, Ln. 274
# ...                                    ...
# 210828           285 Central Park West, #2
# 210829                9481 Gatetrail Drive
# 210830               2822 Millers Run Lane
# 210831                  24 Bullimore Grove
# 210832  Suite 310, 601 West Cordova Street
#
#                                                                                                           name
# 528                                                             6B Chenyu Court; 22-24 Kennedy Road; Hong Kong
# 529            15C Suchun Industrial Square; Suzhou Industrial Park; 215126 Suzhou; People's Republic of China
# 151607                                                 8F., No. 68; Minfu 13th St. Taoyuan County; 330; Taiwan
# 151608                                No. 66, Ln. 20; Dafu Rd., Shengang Township; 429 Taichung County; Taiwan
# 151609  1F., No. 18, Ln. 274; Chang'an St., Luzhou City; Taipei County 247, Taiwan; People's Republic of China
# ...                                                                                                        ...
# 210828                           285 Central Park West, #2; New York; New York 10024; United States of America
# 210829                                     9481 Gatetrail Drive; Dallas; Texas 75238; United States of America
# 210830                                    2822 Millers Run Lane; Lancaster; PA 17601; United States of America
# 210831                                    24 Bullimore Grove; Kenilworth CV8 2QF; Warwickshire; United Kingdom
# 210832                         Suite 310, 601 West Cordova Street; Vancouver; British Columbia V6B 1G1; Canada
#
# [59160 rows x 2 columns]

# %% [markdown]
# ### Swap columns
#
# This is a nifty trick I probably picked up from StackOverflow. The logic behind it is the same as multiple value assignment:
#
# `a, b, c = output_that_gives_multiple_vals(1, 2, 3)`
#
# Or value reassignment:
#
# `a, b = b, a`

# %%
df.loc[df['name'].str.len() > df['address'].str.len(), ['address', 'name']
      ] = df.loc[df['name'].str.len() > df['address'].str.len(), ['name', 'address']].values

# %% [markdown]
# I can't stop there however. When the `address` column is empty, the above logic won't work. A second column value reassignment will take care of this.

# %%
df[df['name'].notna() & df['address'].isna()]
# Out:
#          node_id address  \
# 210833  88000000     NaN
# 210834  88000001     NaN
# 210835  88000002     NaN
# 210836  88000003     NaN
# 210837  88000004     NaN
# ...          ...     ...
# 390990  68001690     NaN
# 390991  68001691     NaN
# 390992  68001692     NaN
# 390993  68001693     NaN
# 390994  68001694     NaN
#
#                                                             name countries  \
# 210833                                    WINDWARD SIDE , , SABA       NaN
# 210834  PISO 3, PUERTA 4, ANDORRA LA VELLA , PRINCIPAT D ANDORRA   Andorra
# 210835                      BLOWING POINT , CUL DE SAC, ANGUILLA  Anguilla
# 210836     CARIBBEAN COMMERCIAL CENTER, POSTBUS 20, ANGUILLA BWI  Anguilla
# 210837   HEYWOOD HOUSE SOUTH HILL, ANGUILLA, BRITISH WEST INDIES  Anguilla
# ...                                                          ...       ...
# 390990                                             Manase, Samoa     Samoa
# 390991                        Vailele-uta, Faleata Sisifo, Samoa     Samoa
# 390992                        Lotopa, Falelatai & Samatau, Samoa     Samoa
# 390993                               Sogi, Vaisigano No.2, Samoa     Samoa
# 390994               Viviena.schaaf, `, Faasaleleaga No.3, Samoa     Samoa
#
#        country_codes                                    sourceID  \
# 210833           NaN  Paradise Papers - Aruba corporate registry
# 210834           AND  Paradise Papers - Aruba corporate registry
# 210835           AIA  Paradise Papers - Aruba corporate registry
# 210836           AIA  Paradise Papers - Aruba corporate registry
# 210837           AIA  Paradise Papers - Aruba corporate registry
# ...              ...                                         ...
# 390990           WSM  Paradise Papers - Samoa corporate registry
# 390991           WSM  Paradise Papers - Samoa corporate registry
# 390992           WSM  Paradise Papers - Samoa corporate registry
# 390993           WSM  Paradise Papers - Samoa corporate registry
# 390994           WSM  Paradise Papers - Samoa corporate registry
#
#                                                   valid_until note
# 210833  Aruba corporate registry data is current through 2016  NaN
# 210834  Aruba corporate registry data is current through 2016  NaN
# 210835  Aruba corporate registry data is current through 2016  NaN
# 210836  Aruba corporate registry data is current through 2016  NaN
# 210837  Aruba corporate registry data is current through 2016  NaN
# ...                                                       ...  ...
# 390990  Samoa corporate registry data is current through 2016  NaN
# 390991  Samoa corporate registry data is current through 2016  NaN
# 390992  Samoa corporate registry data is current through 2016  NaN
# 390993  Samoa corporate registry data is current through 2016  NaN
# 390994  Samoa corporate registry data is current through 2016  NaN
#
# [19930 rows x 8 columns]

# %%
df.loc[df['name'].notna() & df['address'].isna(), ['address', 'name']
      ] = df.loc[df['name'].notna() & df['address'].isna(), ['name', 'address']].values

# %% [markdown]
# ## Country name in `countries` column
#
# Some `country_codes` snuck into some of the values for the countries column. This makes up a relatively small portion of the dataset, but effects quiet a few countries.

# %%
print('Number of country_codes in the wrong column:', df.loc[df['countries'].str.len()<=3, 'countries'].count())
print('Number of unique country codes in the countries column:', df.loc[df['countries'].str.len()<=3, 'countries'].nunique(), '\n')
display(df.loc[df['countries'].str.len()<=3, 'countries'].unique())
# Out:
# Number of country_codes in the wrong column: 1868
# Number of unique country codes in the countries column: 123
# array(['HKG', 'SYC', 'VGB', 'BLZ', 'USA', 'ARE', 'VCT', 'GBR', 'PAN',
#        'MUS', 'MLT', 'AIA', 'SGP', 'BHS', 'CYP', 'KNA', 'LCA', 'LVA',
#        'GIB', 'MHL', 'CHE', 'ESP', 'QAT', 'PRT', 'WSM', 'CZE', 'THA',
#        'ITA', 'BRA', 'ARG', 'ROU', 'FIN', 'FRA', 'POL', 'VNM', 'DNK',
#        'SVK', 'IRL', 'CAN', 'TUR', 'VUT', 'DEU', 'RUS', 'EGY', 'NLD',
#        'GRC', 'ZAF', 'DZA', 'CHL', 'ISR', 'AUS', 'MCO', 'AGO', 'SRB',
#        'IND', 'AND', 'VEN', 'SVN', 'JEY', 'MEX', 'UZB', 'KAZ', 'NOR',
#        'PRY', 'BEL', 'BGR', 'JPN', 'UKR', 'SWE', 'NGA', 'TUN', 'PER',
#        'HUN', 'ECU', 'IDN', 'PHL', 'LUX', 'KEN', 'SAU', 'PAK', 'BLR',
#        'CIV', 'ALB', 'MDG', 'ZMB', 'NZL', 'URY', 'AUT', 'MAR', 'BIH',
#        'HRV', 'COL', 'AZE', 'OMN', 'JOR', 'GHA', 'SMR', 'LAO', 'LBN',
#        'MDA', 'BMU', 'EST', 'SOM', 'MNG', 'BGD', 'MWI', 'NIC', 'GEO',
#        'CUB', 'UGA', 'CYM', 'MYS', 'HND', 'KOR', 'ZWE', 'NAM', 'TZA',
#        'BOL', 'LBY', 'COD', 'PSE', 'BHR', 'LTU'], dtype=object)

# %% [markdown]
# My geography isn't good enough to know what the country name is for each of the codes, so I'll need a way to grab those values.
#
# To address this, I'm going to use the `country_codes` and `countries` columns to create a dictionary with the codes as the key and the country name as the value. I can then use this dictionary to map the country names into the `countries` column. I find this technique useful for all kinds of data wrangling problems as I often need to replace some kind of abbreviation for the actual value or vice versa.

# %%
codes_to_countries = pd.DataFrame(
    df.loc[
        df['countries'].str.len()>3
    ].groupby('country_codes')['countries'
                              ].value_counts()).drop(['countries'], axis=1
                                                    ).reset_index().set_index('country_codes').to_dict()['countries']
codes_to_countries
# Out:
# {'ABW': 'Aruba',
#  'AFG': 'Afghanistan',
#  'AGO': 'Angola',
#  'AIA': 'Anguilla',
#  'ALB': 'Albania',
#  'AND': 'Andorra',
#  'ANT': 'Netherlands Antilles',
#  'ARE': 'United Arab Emirates',
#  'ARG': 'Argentina',
#  'ARM': 'Armenia',
#  'ASM': 'American Samoa',
#  'ATG': 'Antigua and Barbuda',
#  'AUS': 'Australia',
#  'AUT': 'Austria',
#  'AUT;LIE': 'Austria;Liechtenstein',
#  'AZE': 'Azerbaijan',
#  'BEL': 'Belgium',
#  'BEN': 'Benin',
#  'BES': 'Sint Eustatius and Saba Bonaire',
#  'BFA': 'Burkina Faso',
#  'BGD': 'Bangladesh',
#  'BGR': 'Bulgaria',
#  'BHR': 'Bahrain',
#  'BHS': 'Bahamas',
#  'BIH': 'Bosnia and Herzegovina',
#  'BLR': 'Belarus',
#  'BLZ': 'Belize',
#  'BMU': 'Bermuda',
#  'BOL': 'Plurinational State of Bolivia',
#  'BRA': 'Brazil',
#  'BRB': 'Barbados',
#  'BRN': 'Brunei Darussalam',
#  'BTN': 'Bhutan',
#  'BWA': 'Botswana',
#  'CAF': 'Central African Republic',
#  'CAN': 'Canada',
#  'CHE': 'Switzerland',
#  'CHL': 'Chile',
#  'CHN': 'China',
#  'CIV': "Côte d'Ivoire",
#  'CMR': 'Cameroon',
#  'COD': 'The Democratic Republic of the Congo',
#  'COG': 'Congo',
#  'COK': 'Cook Islands',
#  'COL': 'Colombia',
#  'CPV': 'Cape Verde',
#  'CRI': 'Costa Rica',
#  'CUB': 'Cuba',
#  'CUW': 'Curaçao',
#  'CYM': 'Cayman Islands',
#  'CYP': 'Cyprus',
#  'CZE': 'Czech Republic',
#  'DEU': 'Germany',
#  'DJI': 'Djibouti',
#  'DMA': 'Dominica',
#  'DNK': 'Denmark',
#  'DOM': 'Dominican Republic',
#  'DZA': 'Algeria',
#  'ECU': 'Ecuador',
#  'EGY': 'Egypt',
#  'ESP': 'Spain',
#  'EST': 'Estonia',
#  'ETH': 'Ethiopia',
#  'FIN': 'Finland',
#  'FJI': 'Fiji',
#  'FRA': 'France',
#  'GAB': 'Gabon',
#  'GBR': 'United Kingdom',
#  'GEO': 'Georgia',
#  'GGY': 'Guernsey',
#  'GHA': 'Ghana',
#  'GIB': 'Gibraltar',
#  'GIN': 'Guinea',
#  'GMB': 'Gambia',
#  'GNB': 'Guinea-Bissau',
#  'GNQ': 'Equatorial Guinea',
#  'GRC': 'Greece',
#  'GRD': 'Grenada',
#  'GTM': 'Guatemala',
#  'GUF': 'French Guiana',
#  'GUM': 'Guam',
#  'GUY': 'Guyana',
#  'HKG': 'Hong Kong',
#  'HND': 'Honduras',
#  'HRV': 'Croatia',
#  'HTI': 'Haiti',
#  'HUN': 'Hungary',
#  'IDN': 'Indonesia',
#  'IMN': 'Isle of Man',
#  'IMN;GBR': 'Isle of Man;United Kingdom',
#  'IND': 'India',
#  'IOT': 'British Indian Ocean Territory',
#  'IRL': 'Ireland',
#  'IRN': 'Islamic Republic of Iran',
#  'IRQ': 'Iraq',
#  'ISL': 'Iceland',
#  'ISR': 'Israel',
#  'ITA': 'Italy',
#  'JAM': 'Jamaica',
#  'JEY': 'Jersey',
#  'JOR': 'Jordan',
#  'JPN': 'Japan',
#  'KAZ': 'Kazakhstan',
#  'KEN': 'Kenya',
#  'KGZ': 'Kyrgyzstan',
#  'KHM': 'Cambodia',
#  'KIR': 'Kiribati',
#  'KNA': 'Saint Kitts and Nevis',
#  'KOR': 'Korea, Republic of',
#  'KWT': 'Kuwait',
#  'LAO': "Lao People's Democratic Republic",
#  'LBN': 'Lebanon',
#  'LBR': 'Liberia',
#  'LBY': 'Libya',
#  'LCA': 'Saint Lucia',
#  'LIE': 'Liechtenstein',
#  'LKA': 'Sri Lanka',
#  'LSO': 'Lesotho',
#  'LTU': 'Lithuania',
#  'LUX': 'Luxembourg',
#  'LVA': 'Latvia',
#  'MAC': 'Macao',
#  'MAF': 'Saint Martin (French part)',
#  'MAR': 'Morocco',
#  'MCO': 'Monaco',
#  'MDA': 'Republic of Moldova',
#  'MDG': 'Madagascar',
#  'MDV': 'Maldives',
#  'MEX': 'Mexico',
#  'MHL': 'Marshall Islands',
#  'MKD': 'Macedonia',
#  'MLI': 'Mali',
#  'MLT': 'Malta',
#  'MMR': 'Myanmar',
#  'MNE': 'Montenegro',
#  'MNG': 'Mongolia',
#  'MNP': 'Northern Mariana Islands',
#  'MOZ': 'Mozambique',
#  'MTQ': 'Martinique',
#  'MUS': 'Mauritius',
#  'MWI': 'Malawi',
#  'MYS': 'Malaysia',
#  'NAM': 'Namibia',
#  'NCL': 'New Caledonia',
#  'NER': 'Niger',
#  'NFK': 'Norfolk Island',
#  'NGA': 'Nigeria',
#  'NIC': 'Nicaragua',
#  'NIU': 'Niue',
#  'NLD': 'Netherlands',
#  'NOR': 'Norway',
#  'NPL': 'Nepal',
#  'NRU': 'Nauru',
#  'NZL': 'New Zealand',
#  'OMN': 'Oman',
#  'PAK': 'Pakistan',
#  'PAN': 'Panama',
#  'PER': 'Peru',
#  'PHL': 'Philippines',
#  'PNG': 'Papua New Guinea',
#  'POL': 'Poland',
#  'PRI': 'Puerto Rico',
#  'PRK': 'North Korea',
#  'PRT': 'Portugal',
#  'PRY': 'Paraguay',
#  'PSE': 'Palestine',
#  'PYF': 'French Polynesia',
#  'QAT': 'Qatar',
#  'REU': 'Réunion',
#  'ROU': 'Romania',
#  'RUS': 'Russian Federation',
#  'RUS;BLR': 'Russia;Belarus',
#  'RWA': 'Rwanda',
#  'SAU': 'Saudi Arabia',
#  'SDN': 'Sudan',
#  'SEN': 'Senegal',
#  'SGP': 'Singapore',
#  'SLB': 'Solomon Islands',
#  'SLE': 'Sierra Leone',
#  'SLV': 'El Salvador',
#  'SMR': 'San Marino',
#  'SOM': 'Somalia',
#  'SRB': 'Serbia',
#  'STP': 'Sao Tome and Principe',
#  'SUR': 'Suriname',
#  'SVK': 'Slovakia',
#  'SVN': 'Slovenia',
#  'SWE': 'Sweden',
#  'SWZ': 'Swaziland',
#  'SXM': 'Sint Maarten (Dutch part)',
#  'SYC': 'Seychelles',
#  'SYR': 'Syrian Arab Republic',
#  'TCA': 'Turks and Caicos Islands',
#  'TCD': 'Chad',
#  'TGO': 'Togo',
#  'THA': 'Thailand',
#  'TJK': 'Tajikistan',
#  'TKM': 'Turkmenistan',
#  'TON': 'Tonga',
#  'TTO': 'Trinidad and Tobago',
#  'TUN': 'Tunisia',
#  'TUR': 'Turkey',
#  'TUV': 'Tuvalu',
#  'TWN': 'Taiwan, Province of China',
#  'TZA': 'United Republic of Tanzania',
#  'UGA': 'Uganda',
#  'UKR': 'Ukraine',
#  'URY': 'Uruguay',
#  'USA': 'United States',
#  'UZB': 'Uzbekistan',
#  'VCT': 'Saint Vincent and the Grenadines',
#  'VEN': 'Venezuela, Bolivarian Republic of',
#  'VEN;USA': 'Bolivarian Republic of Venezuela;United States',
#  'VGB': 'Virgin Islands, British',
#  'VGB;BRN': 'British Virgin Islands;Brunei Darussalam',
#  'VIR': 'Virgin Islands, U.S.',
#  'VNM': 'Viet Nam',
#  'VUT': 'Vanuatu',
#  'WSM': 'Samoa',
#  'XK': 'Kosovo',
#  'XXX': 'Not identified',
#  'YEM': 'Yemen',
#  'ZAF': 'South Africa',
#  'ZMB': 'Zambia',
#  'ZWE': 'Zimbabwe'}

# %%
df.loc[df['countries'].str.len()<=3, 'countries'] = df.loc[df['countries'].str.len()<=3, 'countries'].map(codes_to_countries)

# %% [markdown]
# ## Break into more managable smaller pieces
#
# Lastly, I decided it would be easier to handle the challenges of each country individually. This will let me to take advantage of any formatting similarities and to become familiar with the way different countries tend to enter address data. This also helps processing time, as I'll be working with smaller datasets and can apply lessons learned between datasets.
#
# There are quite a few countries with low representation, so I grouped those together.

# %%
country_cts = pd.DataFrame(df['countries'].value_counts(dropna=False)).reset_index()
country_cts.columns = ['country', 'count']
country_cts
# Out:
#                                       country   count
# 0                                         NaN  125327
# 1                                       China   32491
# 2                                   Hong Kong   28269
# 3                               United States   24365
# 4                                    Barbados   19348
# ..                                        ...     ...
# 238                             New Caledonia       1
# 239                      Syrian Arab Republic       1
# 240  British Virgin Islands;Brunei Darussalam       1
# 241                     Sao Tome and Principe       1
# 242                Isle of Man;United Kingdom       1
#
# [243 rows x 2 columns]

# %%
country_cts[country_cts['count'] < 500]
# Out:
#                                       country  count
# 66                                      Malta    473
# 67                                     Sweden    422
# 68                                 Costa Rica    417
# 69                             Czech Republic    412
# 70                                 Kazakhstan    411
# ..                                        ...    ...
# 238                             New Caledonia      1
# 239                      Syrian Arab Republic      1
# 240  British Virgin Islands;Brunei Darussalam      1
# 241                     Sao Tome and Principe      1
# 242                Isle of Man;United Kingdom      1
#
# [177 rows x 2 columns]

# %% [markdown]
# ## Save the data
#
# Since I decided to break the data into smaller batches, I need a new folder to save them in.

# %%
# !mkdir data/edited
# Out:
# The syntax of the command is incorrect.

# %%
df[df['countries'].isin(
    country_cts[country_cts['count'] < 500][
        'country'].to_list())].to_csv('data/edited/addresses_low_representation.csv', index=False)

# %%
for country in country_cts[country_cts['count'] >= 500]['country'].to_list():
    df[df['countries'] == country].to_csv('data/edited/addresses_{}.csv'.format(country), index=False)
