# %% [markdown]
# # NLP 06: Word Frequencies

# %% [markdown]
# To be honest, I did a lot of this the hard way to start. It involved manually filtering an Excel spreadsheet version of the addresses, scrolling through thousands of addresses, copy and paste, and making lots of processing mistakes. It occurred to me that a lot of that could have been accomplished by looking at word frequencies, then search the dataset for the most frequent terms.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
from time import gmtime, strftime
import sys
import os
import io

import string
import re

# %%
df = pd.read_csv('data/edited/addresses_Bahamas.csv')

# %% [markdown]
# ## Create a new column to work with
#
# It's important to keep a copy of the original values. This makes it much easier to revert changes that don't perform as expected and also to reference if data is lost or to put it back into context. I've lost count of the number of times I need to walk back a certain processing technique.

# %%
df['working_address'] = df['address']

# %% [markdown]
# ## Word counts
#
# I frequently use word counts to determine any words I need to add to the stopword list (stopwords are words that occur frequently, such as 'the' or 'a' that don't add value to the analysis and should be removed).
#
# In this case, I'm hoping it will bubble up things like cities, states, islands, other address features that occur frequently, and punctuation usage.
#
# First I'll fill  blank lines with an empty string to help full dataset processing (i.e. I really don't want to deal with NANs). Next I lowercase everything (there is no use for "Annex" and "annex" to be two different values in this analysis). Then I split on spaces. Lastly, I reuse the frequency function from [Entry NLP4: Frequencies and Comparison](https://julielinx.github.io/blog/nlp04_vocal_auth_freq_compare/) to get the word counts.

# %%
df['address_wordlist'] = df['working_address'].fillna('').str.lower().str.split()

# %%
df.address_wordlist
# Out:
# 0       [annex, frederick, &, shirley, sts,, p.o., box...
# 1       [suite, e-2,union, court, building,, p.o., box...
# 2       [lyford, cay, house,, lyford, cay,, p.o., box,...
# 3       [p.o., box, n-3708, bahamas, financial, centre...
# 4       [lyford, cay, house,, 3rd, floor,, lyford, cay...
#                               ...
# 2253    [j.p.morgan, trust, company, (bahamas), limite...
# 2254    [montagne, sterline, centre., east, bav, stree...
# 2255    [deltec, house,, lyford, cay,, po, box, n-3229...
# 2256    [providence, house,, hast, wing,, east, hill, ...
# 2257    [c/oj.p., morgan, trust, company, (bahamas), l...
# Name: address_wordlist, Length: 2258, dtype: object

# %%
def frequency_ct(ngram_list):
    freq_dict = {}
    for ngram in ngram_list:
        if ngram not in freq_dict:
            freq_dict[ngram] = 0
        freq_dict[ngram] +=1
    return freq_dict

# %%
freq_df = pd.DataFrame.from_dict(
    frequency_ct(df['address_wordlist'].sum()
                ), orient='index').reset_index().rename(
    columns={'index':'word', 0:'count'}).sort_values('count', ascending=False)

# %%
freq_df.head()
# Out:
#          word  count
# 9     bahamas   2140
# 6         box   1447
# 8     nassau,    974
# 5        p.o.    889
# 1008  nassau;    772

# %% [markdown]
# \**Note*: when applied to a column with lists the `.sum()` function will return a single list. If that column is saved as a `.csv`, then reloaded the list will be read in as a string and `.sum()` will return something that looks like a list of lists, but is a list of strings that were lists.

# %%
df['address_wordlist'].sum()[:15]
# Out:
# ['annex',
#  'frederick',
#  '&',
#  'shirley',
#  'sts,',
#  'p.o.',
#  'box',
#  'n-4805,',
#  'nassau,',
#  'bahamas',
#  'suite',
#  'e-2,union',
#  'court',
#  'building,',
#  'p.o.']

# %%
df.head(10).to_csv('stringified_list.csv', index=False)
str_lst_df = pd.read_csv('stringified_list.csv')

# %%
str_lst_df['address_wordlist'].sum()
# Out:
# '[\'annex\', \'frederick\', \'&\', \'shirley\', \'sts,\', \'p.o.\', \'box\', \'n-4805,\', \'nassau,\', \'bahamas\'][\'suite\', \'e-2,union\', \'court\', \'building,\', \'p.o.\', \'box\', \'n-8188,\', \'nassau,\', \'bahamas\'][\'lyford\', \'cay\', \'house,\', \'lyford\', \'cay,\', \'p.o.\', \'box\', \'n-7785,\', \'nassau,\', \'bahamas\'][\'p.o.\', \'box\', \'n-3708\', \'bahamas\', \'financial\', \'centre,\', \'p.o.\', \'box\', \'n-3708\', \'shirley\', \'&\', \'charlotte\', \'sts,\', \'nassau,\', \'bahamas\'][\'lyford\', \'cay\', \'house,\', \'3rd\', \'floor,\', \'lyford\', \'cay,\', \'p.o.\', \'box\', \'n-3024,\', \'nassau,\', \'bahamas\'][\'303\', \'shirley\', \'street,\', \'p.o.\', \'box\', \'n-492,\', \'nassau,\', \'bahamas\'][\'ocean\', \'centre,\', \'montagu\', \'foreshore,\', \'p.o.\', \'box\', \'ss-19084\', \'east\', \'bay\', \'street,\', \'nassau,\', \'bahamas\'][\'providence\', \'house,\', \'east\', \'wing\', \'east\', \'hill\', \'st,\', \'p.o.\', \'box\', \'cb-12399,\', \'nassau,\', \'bahamas\'][\'bayside\', \'executive\', \'park,\', \'west\', \'bay\', \'&\', \'blake,\', \'p.o.\', \'box\', \'n-4875,\', \'nassau,\', \'bahamas\'][\'ground\', \'floor,\', "goodman\'s", \'bay\', \'corporate\', \'ce,\', \'p.o.\', \'box\', \'n\', \'3933,\', \'nassau,\', \'bahamas\']'

# %% [markdown]
# ## Non-standardizations
#
# I only need to see the top 20 results to start identifying ways to standardize the data.
#
# - PO Boxes are written both as "p.o." and "po"
# - There are both "&" and "and"
#
# I'll double check to make sure these are what I think they are.

# %%
freq_df.head(20)
# Out:
#            word  count
# 9       bahamas   2140
# 6           box   1447
# 8       nassau,    974
# 5          p.o.    889
# 1008    nassau;    772
# 3       shirley    484
# 417          po    461
# 10        suite    445
# 35          bay    405
# 1009    street;    362
# 2             &    325
# 88       street    313
# 1028        and    301
# 101      nassau    272
# 12        court    256
# 23    charlotte    252
# 327      avenue    231
# 1218      union    231
# 183   elizabeth    228
# 125        bank    189

# %%
pd.set_option('display.max_colwidth', 1000)

# %%
df[df['working_address'].str.lower().str.contains('p\.?o\.?', regex=True)].tail()
# Out:
#         node_id  \
# 2225  240491356
# 2227  240491474
# 2229  240491518
# 2255  240491733
# 2256  240491778
#
#                                                                                                             address  \
# 2225  P.O. BOX N- 3944, SUITE 200B, 2ND FLOOR, CENTRE OF COMMERCE, ONE BAY STREET, NASSAU, BAHAMAS, NASSAU, BAHAMAS
# 2227                      SUITE 200B, 2ND FLOOR, CENTRE OF COMMERCE, ONE BAY STREET, PO BOX N-3944, NASSAU, BAHAMAS
# 2229    RBC TRUST COMPANY (BAHAMAS) LIMITED, BAYSIDE EXECUTIVE PARK BUILDING 3, P.O. BOX NO. 30-24, NASSAU, BAHAMAS
# 2255                                                       DELTEC HOUSE, LYFORD CAY, PO BOX N-3229, NASSAU, BAHAMAS
# 2256                    PROVIDENCE HOUSE, HAST WING, EAST HILL STREET, P.O. BOX CB-12399, NASSAU, CB-12399, BAHAMAS
#
#      name countries country_codes                        sourceID  \
# 2225  NaN   Bahamas           BHS  Pandora Papers - Trident Trust
# 2227  NaN   Bahamas           BHS  Pandora Papers - Trident Trust
# 2229  NaN   Bahamas           BHS  Pandora Papers - Trident Trust
# 2255  NaN   Bahamas           BHS  Pandora Papers - Trident Trust
# 2256  NaN   Bahamas           BHS  Pandora Papers - Trident Trust
#
#                                 valid_until note  \
# 2225  Provider data is current through 2017  NaN
# 2227  Provider data is current through 2016  NaN
# 2229  Provider data is current through 2016  NaN
# 2255  Provider data is current through 2016  NaN
# 2256  Provider data is current through 2016  NaN
#
#                                                                                                     working_address  \
# 2225  P.O. BOX N- 3944, SUITE 200B, 2ND FLOOR, CENTRE OF COMMERCE, ONE BAY STREET, NASSAU, BAHAMAS, NASSAU, BAHAMAS
# 2227                      SUITE 200B, 2ND FLOOR, CENTRE OF COMMERCE, ONE BAY STREET, PO BOX N-3944, NASSAU, BAHAMAS
# 2229    RBC TRUST COMPANY (BAHAMAS) LIMITED, BAYSIDE EXECUTIVE PARK BUILDING 3, P.O. BOX NO. 30-24, NASSAU, BAHAMAS
# 2255                                                       DELTEC HOUSE, LYFORD CAY, PO BOX N-3229, NASSAU, BAHAMAS
# 2256                    PROVIDENCE HOUSE, HAST WING, EAST HILL STREET, P.O. BOX CB-12399, NASSAU, CB-12399, BAHAMAS
#
#                                                                                                                       address_wordlist
# 2225  [p.o., box, n-, 3944,, suite, 200b,, 2nd, floor,, centre, of, commerce,, one, bay, street,, nassau,, bahamas,, nassau,, bahamas]
# 2227                         [suite, 200b,, 2nd, floor,, centre, of, commerce,, one, bay, street,, po, box, n-3944,, nassau,, bahamas]
# 2229      [rbc, trust, company, (bahamas), limited,, bayside, executive, park, building, 3,, p.o., box, no., 30-24,, nassau,, bahamas]
# 2255                                                                [deltec, house,, lyford, cay,, po, box, n-3229,, nassau,, bahamas]
# 2256                         [providence, house,, hast, wing,, east, hill, street,, p.o., box, cb-12399,, nassau,, cb-12399,, bahamas]

# %% [markdown]
# Even in just these five rows, I can see "po box" and "p.o. box" are both represented.

# %%
df[df['working_address'].str.lower().str.contains('p\.?o\.?b', regex=True)].tail()
# Out:
#         node_id  \
# 1807   88017491
# 2123  120000350
# 2143  120010247
# 2150  120006606
# 2193  240001242
#
#                                                                                    address  \
# 1807                   BOLAM HOUSE, KING AND GEORGE STREETS P.O.BOX N-514, NASSAU, BAHAMAS
# 2123                SAFFREY SQUARE, SUITE 205 BANK LANE, P.O.BOX N, 8188, NASSAU, BAHAMAS.
# 2143             LENNOX PATON CORPORATE SERVICES LIMITED, P.O.BOX N-4875, NASSAU, BAHAMAS.
# 2150  OCEAN CENTRE, MONTAGU FORESHORE, EAST BAY STREET, P.O.BOX SS-19084, NASSAU, BAHAMAS.
# 2193                     DOMINION HOUSE60,MONTROSE AVENUE, P.O.BOX N-9932, NASSAU, BAHAMAS
#
#                                                                                       name  \
# 1807                                                                                   NaN
# 2123                SAFFREY SQUARE, SUITE 205 BANK LANE, P.O.BOX N, 8188, NASSAU, BAHAMAS.
# 2143             LENNOX PATON CORPORATE SERVICES LIMITED, P.O.BOX N-4875, NASSAU, BAHAMAS.
# 2150  OCEAN CENTRE, MONTAGU FORESHORE, EAST BAY STREET, P.O.BOX SS-19084, NASSAU, BAHAMAS.
# 2193                                                                                   NaN
#
#      countries country_codes  \
# 1807   Bahamas           BHS
# 2123   Bahamas           BHS
# 2143   Bahamas           BHS
# 2150   Bahamas           BHS
# 2193   Bahamas           BHS
#
#                                                        sourceID  \
# 1807                 Paradise Papers - Aruba corporate registry
# 2123              Paradise Papers - Barbados corporate registry
# 2143              Paradise Papers - Barbados corporate registry
# 2150              Paradise Papers - Barbados corporate registry
# 2193  Pandora Papers - Alemán, Cordero, Galindo & Lee (Alcogal)
#
#                                                    valid_until note  \
# 1807     Aruba corporate registry data is current through 2016  NaN
# 2123  Barbados corporate registry data is current through 2016  NaN
# 2143  Barbados corporate registry data is current through 2016  NaN
# 2150  Barbados corporate registry data is current through 2016  NaN
# 2193                     Provider data is current through 2018  NaN
#
#                                                                            working_address  \
# 1807                   BOLAM HOUSE, KING AND GEORGE STREETS P.O.BOX N-514, NASSAU, BAHAMAS
# 2123                SAFFREY SQUARE, SUITE 205 BANK LANE, P.O.BOX N, 8188, NASSAU, BAHAMAS.
# 2143             LENNOX PATON CORPORATE SERVICES LIMITED, P.O.BOX N-4875, NASSAU, BAHAMAS.
# 2150  OCEAN CENTRE, MONTAGU FORESHORE, EAST BAY STREET, P.O.BOX SS-19084, NASSAU, BAHAMAS.
# 2193                     DOMINION HOUSE60,MONTROSE AVENUE, P.O.BOX N-9932, NASSAU, BAHAMAS
#
#                                                                                       address_wordlist
# 1807                    [bolam, house,, king, and, george, streets, p.o.box, n-514,, nassau,, bahamas]
# 2123                [saffrey, square,, suite, 205, bank, lane,, p.o.box, n,, 8188,, nassau,, bahamas.]
# 2143               [lennox, paton, corporate, services, limited,, p.o.box, n-4875,, nassau,, bahamas.]
# 2150  [ocean, centre,, montagu, foreshore,, east, bay, street,, p.o.box, ss-19084,, nassau,, bahamas.]
# 2193                         [dominion, house60,montrose, avenue,, p.o.box, n-9932,, nassau,, bahamas]

# %% [markdown]
# If I dive a little further, I also see there are some instances where the two words are run together, punctuation other than "." separates the letters, and even a few where the "po" or "po box" portion has been left off entirely.

# %%
df[~df['working_address'].str.lower().str.contains('p\.?o\.?', regex=True)].head(10)
# Out:
#       node_id  \
# 235  24000236
# 255  24000256
# 290  24000291
# 484  24000485
# 485  24000486
# 517  24000518
# 529  14000065
# 530  14000073
# 535  14007586
# 536  14000678
#
#                                                                                              address  \
# 235                   #4 PINEAPPLE GROVE,OLD FORT BAY, NEW PRODIVENCE, BOX SP-60063, NASSAU, BAHAMAS
# 255                                                                          P,O, BOX N-4759, NASSAU
# 290                                             3RD FLOOR TRADE WINDS BLDG, BAY ST P>O. BOX CB 12724
# 484                                                            #70 WULFF ROAD, NASSAU, BAHAMAS N-989
# 485                                                                                   DEVEAUX STREET
# 517  3RD FL. BRITISH COLONIAL CENTRE OF COMM, SUITE 304, 1 BAY STREET, SP 63776, NASSAU, NP, BAHAMAS
# 529                                               #1 Bay Street; Centre of Commerce Nassau; Bahamas.
# 530                           #1 Venetian Villa N492; Old Fort Day; Nassau; New Providence; Bahamas.
# 535                            1st FLOOR; EURO CANADIAN CENTRE; MARLBOROUGHT STREET; NASSAU; BAHAMAS
# 536                                                              101 East Hill Street, Nasau Bahamas
#
#     name countries country_codes       sourceID  \
# 235  NaN   Bahamas           BHS  Bahamas Leaks
# 255  NaN   Bahamas           BHS  Bahamas Leaks
# 290  NaN   Bahamas           BHS  Bahamas Leaks
# 484  NaN   Bahamas           BHS  Bahamas Leaks
# 485  NaN   Bahamas           BHS  Bahamas Leaks
# 517  NaN   Bahamas           BHS  Bahamas Leaks
# 529  NaN   Bahamas           BHS  Panama Papers
# 530  NaN   Bahamas           BHS  Panama Papers
# 535  NaN   Bahamas           BHS  Panama Papers
# 536  NaN   Bahamas           BHS  Panama Papers
#
#                                                valid_until note  \
# 235  The Bahamas Leaks data is current through early 2016.  NaN
# 255  The Bahamas Leaks data is current through early 2016.  NaN
# 290  The Bahamas Leaks data is current through early 2016.  NaN
# 484  The Bahamas Leaks data is current through early 2016.  NaN
# 485  The Bahamas Leaks data is current through early 2016.  NaN
# 517  The Bahamas Leaks data is current through early 2016.  NaN
# 529        The Panama Papers  data is current through 2015  NaN
# 530        The Panama Papers  data is current through 2015  NaN
# 535        The Panama Papers  data is current through 2015  NaN
# 536        The Panama Papers  data is current through 2015  NaN
#
#                                                                                      working_address  \
# 235                   #4 PINEAPPLE GROVE,OLD FORT BAY, NEW PRODIVENCE, BOX SP-60063, NASSAU, BAHAMAS
# 255                                                                          P,O, BOX N-4759, NASSAU
# 290                                             3RD FLOOR TRADE WINDS BLDG, BAY ST P>O. BOX CB 12724
# 484                                                            #70 WULFF ROAD, NASSAU, BAHAMAS N-989
# 485                                                                                   DEVEAUX STREET
# 517  3RD FL. BRITISH COLONIAL CENTRE OF COMM, SUITE 304, 1 BAY STREET, SP 63776, NASSAU, NP, BAHAMAS
# 529                                               #1 Bay Street; Centre of Commerce Nassau; Bahamas.
# 530                           #1 Venetian Villa N492; Old Fort Day; Nassau; New Providence; Bahamas.
# 535                            1st FLOOR; EURO CANADIAN CENTRE; MARLBOROUGHT STREET; NASSAU; BAHAMAS
# 536                                                              101 East Hill Street, Nasau Bahamas
#
#                                                                                                       address_wordlist
# 235                         [#4, pineapple, grove,old, fort, bay,, new, prodivence,, box, sp-60063,, nassau,, bahamas]
# 255                                                                                       [p,o,, box, n-4759,, nassau]
# 290                                                   [3rd, floor, trade, winds, bldg,, bay, st, p>o., box, cb, 12724]
# 484                                                                       [#70, wulff, road,, nassau,, bahamas, n-989]
# 485                                                                                                  [deveaux, street]
# 517  [3rd, fl., british, colonial, centre, of, comm,, suite, 304,, 1, bay, street,, sp, 63776,, nassau,, np,, bahamas]
# 529                                                        [#1, bay, street;, centre, of, commerce, nassau;, bahamas.]
# 530                                 [#1, venetian, villa, n492;, old, fort, day;, nassau;, new, providence;, bahamas.]
# 535                                    [1st, floor;, euro, canadian, centre;, marlborought, street;, nassau;, bahamas]
# 536                                                                         [101, east, hill, street,, nasau, bahamas]

# %%
df[df['working_address'].str.lower().str.contains('&|and')]
# Out:
#         node_id  \
# 0      24000001
# 3      24000004
# 8      24000009
# 10     24000011
# 11     24000012
# ...         ...
# 2244  240492203
# 2245  240492204
# 2246  240492207
# 2248  240492221
# 2257  240491892
#
#                                                                                                                                                      address  \
# 0                                                                                            ANNEX FREDERICK & SHIRLEY STS, P.O. BOX N-4805, NASSAU, BAHAMAS
# 3                                                         P.O. BOX N-3708 BAHAMAS FINANCIAL CENTRE, P.O. BOX N-3708 SHIRLEY & CHARLOTTE STS, NASSAU, BAHAMAS
# 8                                                                                 BAYSIDE EXECUTIVE PARK, WEST BAY & BLAKE, P.O. BOX N-4875, NASSAU, BAHAMAS
# 10                                                                TK HOUSE, BAYSIDE EXECUTIVE PARK, P.O. BOX AP-59213 WEST BAY & BLAKE ROAD, NASSAU, BAHAMAS
# 11                                                                                   BAYSIDE HOUSE WEST BAY & BLAKE ROAD, P.O. BOX AP-59213, NASSAU, BAHAMAS
# ...                                                                                                                                                      ...
# 2244  J.P. MORGAN TRUST COMPANY (BAHAMAS) LIMITED, 2ND FLOOR BAHAMAS FINANCIAL CENTRE, SHIRLEY AND CHARLOTTE STREET, NASSAU, N-4899, NEW PROVIDENCE, BAHAMAS
# 2245                  J.P. MORGAN TRUST COMPANY (BAHAMAS) LIMITED, 2ND FLOOR BAHAMAS FINANCIAL CENTRE, SHIRLEY AND CHARLOTTE STREET, NASSAU, N-4899, BAHAMAS
# 2246                                                                                         SHIRLEY AND CHARLOTTE STREETS, NASSAU, COUNTRY BAHAMAS, BAHAMAS
# 2248                            JPMORGAN TRUST COMPANY (BAHAMAS) LIMITED, 2ND FLOOR, BAHAMAS FINANCIAL CENTRE, SHIRLEY AND CHARLOTTE STREET, NASSAU, BAHAMAS
# 2257             C/OJ.P. MORGAN TRUST COMPANY (BAHAMAS) LIMITED, BAHAMAS FINANCIAL CENTER 2NTL FLOOR, SHIRLEY AND CHARLOTTE STREETS, NASSAU, N-4899, BAHAMAS
#
#      name countries country_codes                        sourceID  \
# 0     NaN   Bahamas           BHS                   Bahamas Leaks
# 3     NaN   Bahamas           BHS                   Bahamas Leaks
# 8     NaN   Bahamas           BHS                   Bahamas Leaks
# 10    NaN   Bahamas           BHS                   Bahamas Leaks
# 11    NaN   Bahamas           BHS                   Bahamas Leaks
# ...   ...       ...           ...                             ...
# 2244  NaN   Bahamas           BHS  Pandora Papers - Trident Trust
# 2245  NaN   Bahamas           BHS  Pandora Papers - Trident Trust
# 2246  NaN   Bahamas           BHS  Pandora Papers - Trident Trust
# 2248  NaN   Bahamas           BHS  Pandora Papers - Trident Trust
# 2257  NaN   Bahamas           BHS  Pandora Papers - Trident Trust
#
#                                                 valid_until note  \
# 0     The Bahamas Leaks data is current through early 2016.  NaN
# 3     The Bahamas Leaks data is current through early 2016.  NaN
# 8     The Bahamas Leaks data is current through early 2016.  NaN
# 10    The Bahamas Leaks data is current through early 2016.  NaN
# 11    The Bahamas Leaks data is current through early 2016.  NaN
# ...                                                     ...  ...
# 2244                  Provider data is current through 2017  NaN
# 2245                  Provider data is current through 2017  NaN
# 2246                  Provider data is current through 2016  NaN
# 2248                  Provider data is current through 2017  NaN
# 2257                  Provider data is current through 2017  NaN
#
#                                                                                                                                              working_address  \
# 0                                                                                            ANNEX FREDERICK & SHIRLEY STS, P.O. BOX N-4805, NASSAU, BAHAMAS
# 3                                                         P.O. BOX N-3708 BAHAMAS FINANCIAL CENTRE, P.O. BOX N-3708 SHIRLEY & CHARLOTTE STS, NASSAU, BAHAMAS
# 8                                                                                 BAYSIDE EXECUTIVE PARK, WEST BAY & BLAKE, P.O. BOX N-4875, NASSAU, BAHAMAS
# 10                                                                TK HOUSE, BAYSIDE EXECUTIVE PARK, P.O. BOX AP-59213 WEST BAY & BLAKE ROAD, NASSAU, BAHAMAS
# 11                                                                                   BAYSIDE HOUSE WEST BAY & BLAKE ROAD, P.O. BOX AP-59213, NASSAU, BAHAMAS
# ...                                                                                                                                                      ...
# 2244  J.P. MORGAN TRUST COMPANY (BAHAMAS) LIMITED, 2ND FLOOR BAHAMAS FINANCIAL CENTRE, SHIRLEY AND CHARLOTTE STREET, NASSAU, N-4899, NEW PROVIDENCE, BAHAMAS
# 2245                  J.P. MORGAN TRUST COMPANY (BAHAMAS) LIMITED, 2ND FLOOR BAHAMAS FINANCIAL CENTRE, SHIRLEY AND CHARLOTTE STREET, NASSAU, N-4899, BAHAMAS
# 2246                                                                                         SHIRLEY AND CHARLOTTE STREETS, NASSAU, COUNTRY BAHAMAS, BAHAMAS
# 2248                            JPMORGAN TRUST COMPANY (BAHAMAS) LIMITED, 2ND FLOOR, BAHAMAS FINANCIAL CENTRE, SHIRLEY AND CHARLOTTE STREET, NASSAU, BAHAMAS
# 2257             C/OJ.P. MORGAN TRUST COMPANY (BAHAMAS) LIMITED, BAHAMAS FINANCIAL CENTER 2NTL FLOOR, SHIRLEY AND CHARLOTTE STREETS, NASSAU, N-4899, BAHAMAS
#
#                                                                                                                                                                  address_wordlist
# 0                                                                                                      [annex, frederick, &, shirley, sts,, p.o., box, n-4805,, nassau,, bahamas]
# 3                                                              [p.o., box, n-3708, bahamas, financial, centre,, p.o., box, n-3708, shirley, &, charlotte, sts,, nassau,, bahamas]
# 8                                                                                         [bayside, executive, park,, west, bay, &, blake,, p.o., box, n-4875,, nassau,, bahamas]
# 10                                                                     [tk, house,, bayside, executive, park,, p.o., box, ap-59213, west, bay, &, blake, road,, nassau,, bahamas]
# 11                                                                                           [bayside, house, west, bay, &, blake, road,, p.o., box, ap-59213,, nassau,, bahamas]
# ...                                                                                                                                                                           ...
# 2244  [j.p., morgan, trust, company, (bahamas), limited,, 2nd, floor, bahamas, financial, centre,, shirley, and, charlotte, street,, nassau,, n-4899,, new, providence,, bahamas]
# 2245                    [j.p., morgan, trust, company, (bahamas), limited,, 2nd, floor, bahamas, financial, centre,, shirley, and, charlotte, street,, nassau,, n-4899,, bahamas]
# 2246                                                                                                     [shirley, and, charlotte, streets,, nassau,, country, bahamas,, bahamas]
# 2248                                [jpmorgan, trust, company, (bahamas), limited,, 2nd, floor,, bahamas, financial, centre,, shirley, and, charlotte, street,, nassau,, bahamas]
# 2257               [c/oj.p., morgan, trust, company, (bahamas), limited,, bahamas, financial, center, 2ntl, floor,, shirley, and, charlotte, streets,, nassau,, n-4899,, bahamas]
#
# [773 rows x 10 columns]

# %% [markdown]
# ### St
#
# "st" is a complicated one. It's short for "street"; appears at the end of "east", "west", "first", and "trust;" is at the start of the word "street;" and is an abreviation for "saint."

# %%
df[df['address_wordlist'].apply(lambda x: 'st' in x)]
# Out:
#        node_id  \
# 225   24000226
# 290   24000291
# 374   24000375
# 1595  81031897
# 1814  33000002
# 1832  33000020
# 1923  33000119
# 1935  33000132
# 1958  33000157
# 1959  33000158
# 1965  33000164
# 2036  33000242
# 2045  33000252
# 2077  33000284
# 2093  33000301
# 2096  33000304
# 2097  33000305
# 2104  33000313
#
#                                                                                        address  \
# 225                    1 BAY ST 3RD FL BRITISH COLONIAL CENTRE, P.O. BOX 7115, NASSAU, BAHAMAS
# 290                                       3RD FLOOR TRADE WINDS BLDG, BAY ST P>O. BOX CB 12724
# 374                    #2 DEWGARD PLAZA BRADLEY ST PALMDALE, P.O. BOX SS-5062, NASSAU, BAHAMAS
# 1595                           Sassoon House; Shirley St and Victoria Ave; Nassau; NP; Bahamas
# 1814                    31B, ANNEX BUILDING EAST BAY ST 2ND FL, PO BOX N-3930, NASSAU, BAHAMAS
# 1832                         #10 PETRONA HOUSE, FOWLER ST EAST, PO BOX N 1375, NASSAU, BAHAMAS
# 1923             LYFORD MANOR, WEST BUILDING, WEST BAY ST PO BOX CB-13007, NASSAU, NP, BAHAMAS
# 1935                       ST ANDREW'S COURT FREDERICK ST STEPS PO BOX N-4805, NASSAU, BAHAMAS
# 1958                                 #308 EAST BAY ST 4TH FLOOR PO BOX N-7768, NASSAU, BAHAMAS
# 1959                  WINTERBOTHAM PLC MARLBOROUGH & QUEEN ST PO BOX CB-11343, NASSAU, BAHAMAS
# 1965                                     308 EAST BAY ST 3RD FL PO BOX N-7527, NASSAU, BAHAMAS
# 2036  SUITE #102 SAFFREY SQUARE 1ST FLOOR, PO BOX CB-13937 BAY ST & BANK LANE, NASSAU, BAHAMAS
# 2045                  3RD FLOOR, ONE MONTAGUE PLACE, EAST BAY ST PO BOX N3231, NASSAU, BAHAMAS
# 2077                   OLDE TOWNE MARINA SANDY PORT WEST BAY ST PO BOX N-4825, NASSAU, BAHAMAS
# 2093                  GOODMAN'S CORPORATE CENTER, WEST BAY ST PO BOX SP-61567, NASSAU, BAHAMAS
# 2096                 PROVIDENCE HOUSE, EAST WING EAST HILL ST PO BOX CB-12399, NASSAU, BAHAMAS
# 2097                   SASSOON HOUSE SHIRLEY ST & VICTORIA AVE PO BOX SS-5383, NASSAU, BAHAMAS
# 2104                               CAVES VILLAGE, WEST BAY ST PO BOX SP-63801, NASSAU, BAHAMAS
#
#                name countries country_codes  \
# 225             NaN   Bahamas           BHS
# 290             NaN   Bahamas           BHS
# 374             NaN   Bahamas           BHS
# 1595  Sassoon House   Bahamas           BHS
# 1814            NaN   Bahamas           BHS
# 1832            NaN   Bahamas           BHS
# 1923            NaN   Bahamas           BHS
# 1935            NaN   Bahamas           BHS
# 1958            NaN   Bahamas           BHS
# 1959            NaN   Bahamas           BHS
# 1965            NaN   Bahamas           BHS
# 2036            NaN   Bahamas           BHS
# 2045            NaN   Bahamas           BHS
# 2077            NaN   Bahamas           BHS
# 2093            NaN   Bahamas           BHS
# 2096            NaN   Bahamas           BHS
# 2097            NaN   Bahamas           BHS
# 2104            NaN   Bahamas           BHS
#
#                                           sourceID  \
# 225                                  Bahamas Leaks
# 290                                  Bahamas Leaks
# 374                                  Bahamas Leaks
# 1595                     Paradise Papers - Appleby
# 1814  Paradise Papers - Bahamas corporate registry
# 1832  Paradise Papers - Bahamas corporate registry
# 1923  Paradise Papers - Bahamas corporate registry
# 1935  Paradise Papers - Bahamas corporate registry
# 1958  Paradise Papers - Bahamas corporate registry
# 1959  Paradise Papers - Bahamas corporate registry
# 1965  Paradise Papers - Bahamas corporate registry
# 2036  Paradise Papers - Bahamas corporate registry
# 2045  Paradise Papers - Bahamas corporate registry
# 2077  Paradise Papers - Bahamas corporate registry
# 2093  Paradise Papers - Bahamas corporate registry
# 2096  Paradise Papers - Bahamas corporate registry
# 2097  Paradise Papers - Bahamas corporate registry
# 2104  Paradise Papers - Bahamas corporate registry
#
#                                                   valid_until note  \
# 225     The Bahamas Leaks data is current through early 2016.  NaN
# 290     The Bahamas Leaks data is current through early 2016.  NaN
# 374     The Bahamas Leaks data is current through early 2016.  NaN
# 1595                     Appleby data is current through 2014  NaN
# 1814  Bahamas corporate registry data is current through 2016  NaN
# 1832  Bahamas corporate registry data is current through 2016  NaN
# 1923  Bahamas corporate registry data is current through 2016  NaN
# 1935  Bahamas corporate registry data is current through 2016  NaN
# 1958  Bahamas corporate registry data is current through 2016  NaN
# 1959  Bahamas corporate registry data is current through 2016  NaN
# 1965  Bahamas corporate registry data is current through 2016  NaN
# 2036  Bahamas corporate registry data is current through 2016  NaN
# 2045  Bahamas corporate registry data is current through 2016  NaN
# 2077  Bahamas corporate registry data is current through 2016  NaN
# 2093  Bahamas corporate registry data is current through 2016  NaN
# 2096  Bahamas corporate registry data is current through 2016  NaN
# 2097  Bahamas corporate registry data is current through 2016  NaN
# 2104  Bahamas corporate registry data is current through 2016  NaN
#
#                                                                                working_address  \
# 225                    1 BAY ST 3RD FL BRITISH COLONIAL CENTRE, P.O. BOX 7115, NASSAU, BAHAMAS
# 290                                       3RD FLOOR TRADE WINDS BLDG, BAY ST P>O. BOX CB 12724
# 374                    #2 DEWGARD PLAZA BRADLEY ST PALMDALE, P.O. BOX SS-5062, NASSAU, BAHAMAS
# 1595                           Sassoon House; Shirley St and Victoria Ave; Nassau; NP; Bahamas
# 1814                    31B, ANNEX BUILDING EAST BAY ST 2ND FL, PO BOX N-3930, NASSAU, BAHAMAS
# 1832                         #10 PETRONA HOUSE, FOWLER ST EAST, PO BOX N 1375, NASSAU, BAHAMAS
# 1923             LYFORD MANOR, WEST BUILDING, WEST BAY ST PO BOX CB-13007, NASSAU, NP, BAHAMAS
# 1935                       ST ANDREW'S COURT FREDERICK ST STEPS PO BOX N-4805, NASSAU, BAHAMAS
# 1958                                 #308 EAST BAY ST 4TH FLOOR PO BOX N-7768, NASSAU, BAHAMAS
# 1959                  WINTERBOTHAM PLC MARLBOROUGH & QUEEN ST PO BOX CB-11343, NASSAU, BAHAMAS
# 1965                                     308 EAST BAY ST 3RD FL PO BOX N-7527, NASSAU, BAHAMAS
# 2036  SUITE #102 SAFFREY SQUARE 1ST FLOOR, PO BOX CB-13937 BAY ST & BANK LANE, NASSAU, BAHAMAS
# 2045                  3RD FLOOR, ONE MONTAGUE PLACE, EAST BAY ST PO BOX N3231, NASSAU, BAHAMAS
# 2077                   OLDE TOWNE MARINA SANDY PORT WEST BAY ST PO BOX N-4825, NASSAU, BAHAMAS
# 2093                  GOODMAN'S CORPORATE CENTER, WEST BAY ST PO BOX SP-61567, NASSAU, BAHAMAS
# 2096                 PROVIDENCE HOUSE, EAST WING EAST HILL ST PO BOX CB-12399, NASSAU, BAHAMAS
# 2097                   SASSOON HOUSE SHIRLEY ST & VICTORIA AVE PO BOX SS-5383, NASSAU, BAHAMAS
# 2104                               CAVES VILLAGE, WEST BAY ST PO BOX SP-63801, NASSAU, BAHAMAS
#
#                                                                                                address_wordlist
# 225                       [1, bay, st, 3rd, fl, british, colonial, centre,, p.o., box, 7115,, nassau,, bahamas]
# 290                                            [3rd, floor, trade, winds, bldg,, bay, st, p>o., box, cb, 12724]
# 374                         [#2, dewgard, plaza, bradley, st, palmdale,, p.o., box, ss-5062,, nassau,, bahamas]
# 1595                                 [sassoon, house;, shirley, st, and, victoria, ave;, nassau;, np;, bahamas]
# 1814                       [31b,, annex, building, east, bay, st, 2nd, fl,, po, box, n-3930,, nassau,, bahamas]
# 1832                             [#10, petrona, house,, fowler, st, east,, po, box, n, 1375,, nassau,, bahamas]
# 1923                [lyford, manor,, west, building,, west, bay, st, po, box, cb-13007,, nassau,, np,, bahamas]
# 1935                            [st, andrew's, court, frederick, st, steps, po, box, n-4805,, nassau,, bahamas]
# 1958                                      [#308, east, bay, st, 4th, floor, po, box, n-7768,, nassau,, bahamas]
# 1959                       [winterbotham, plc, marlborough, &, queen, st, po, box, cb-11343,, nassau,, bahamas]
# 1965                                          [308, east, bay, st, 3rd, fl, po, box, n-7527,, nassau,, bahamas]
# 2036  [suite, #102, saffrey, square, 1st, floor,, po, box, cb-13937, bay, st, &, bank, lane,, nassau,, bahamas]
# 2045                     [3rd, floor,, one, montague, place,, east, bay, st, po, box, n3231,, nassau,, bahamas]
# 2077                      [olde, towne, marina, sandy, port, west, bay, st, po, box, n-4825,, nassau,, bahamas]
# 2093                       [goodman's, corporate, center,, west, bay, st, po, box, sp-61567,, nassau,, bahamas]
# 2096                     [providence, house,, east, wing, east, hill, st, po, box, cb-12399,, nassau,, bahamas]
# 2097                       [sassoon, house, shirley, st, &, victoria, ave, po, box, ss-5383,, nassau,, bahamas]
# 2104                                     [caves, village,, west, bay, st, po, box, sp-63801,, nassau,, bahamas]

# %%
df[df['address_wordlist'].apply(lambda x: 'st.' in x)]
# Out:
#         node_id  \
# 12     24000013
# 16     24000017
# 21     24000022
# 34     24000035
# 37     24000038
# 78     24000079
# 93     24000094
# 125    24000126
# 343    24000344
# 406    24000407
# 450    24000451
# 622    14030198
# 661    14032773
# 704    14036513
# 960    14078480
# 961    14078481
# 996    14079953
# 1009   14079967
# 1134   14082116
# 1563   81024981
# 2127  120005466
# 2161  120015591
#
#                                                                                                                                              address  \
# 12                                                                                     #308 EAST BAY ST. 4TH FLOOR, P.O. BOX N-7768, NASSAU, BAHAMAS
# 16                                                                       SASSOON HOUSE SHIRLEY ST. & VICTORIA AVE, P.O. BOX SS-5383, NASSAU, BAHAMAS
# 21                                                                       3RD FLOOR, ONE MONTAGUE PLACE, EAST BAY ST. P.O. BOX N3231, NASSAU, BAHAMAS
# 34                                                                        31B, ANNEX BUILDING EAST BAY ST. 2ND FL., P.O. BOX N-3930, NASSAU, BAHAMAS
# 37                                                       SUITE #102 SAFFREY SQUARE 1ST FLOOR, P.O. BOX CB-13937 BAY ST. & BANK LANE, NASSAU, BAHAMAS
# 78                                                                              #10 PETRONA HOUSE, FOWLER ST. EAST, P.O. BOX N 1375, NASSAU, BAHAMAS
# 93                                                                                        308 EAST BAY ST. 3RD FL., P.O. BOX N-7527, NASSAU, BAHAMAS
# 125                                                                        3RD FLOOR, MARITIME HOUSE, FREDERICK ST. P.O. BOX N-4584, NASSAU, BAHAMAS
# 343                                                                                 DOWDESWELL ST. KI-MALEX HOUSE, P.O. BOX SS-6836, NASSAU, BAHAMAS
# 406                                                                               MALBOROUGH ST. & NAVY LION RD., P.O. BOX SS-19051, NASSAU, BAHAMAS
# 450                                                                      ST. MALCOLM BUILDING, VICTORIA & BAY STS, P.O. BOX SS-6738, NASSAU, BAHAMAS
# 622   BAHAMAS FINANCIAL CENTRE; SHIRLEY 7 CHARLOTTE STREET; FOURTH FLOOR; NASSAU BAHAMAS FINANCIAL CENTRE; SHIRLEY 7 CHARLOTTE ST. 4TH FLOOR; NASSAU
# 661                                  c/o GTC Corporate Services Limited; Sassoon House; Shirley St. & Victoria Ave.; PO Box SS-5383; Nassau; Bahamas
# 704                                                                                    Conchrest 6 A West Bay St. P.O. Box CB 10974; Nassau; Bahamas
# 960                                                                                      St. Andrew's Court; Frederick Street Steps; Nassau; Bahamas
# 961                                                                    St. Andrew's Court; Frederick Street Steps; P. O. Box N-4805; Nassau; Bahamas
# 996                                                                      Suite E-2; Union Court Bldg.; Elizabeth Av. and Shirley St.  Nassau Bahamas
# 1009                                                                        Suite E2 Union Court Building Elisabeth Ave. Shirley St. Nassau, Bahamas
# 1134                                                                               UNION COURT BLDG ELISABETH AVE AND SHIRLEY ST. NASSAU THE BAHAMAS
# 1563                                                        Sasoon House; Shirley St. & Victoria Ave.; PO Box N-272; Nassau; New Providence; Bahamas
# 2127                                TRIDENT CORPORATE SERVICES (BAHAMAS), LIMITED, PROVIDENCE HOUSE, EAST HILL ST. P.O. BOX N-3944, NASSAU, BAHAMAS.
# 2161                                                                                      ST. ANDREW'S COURT FREDERICK STREET, STEPS, NASSAU BAHAMAS
#
#                                                                                                                   name  \
# 12                                                                                                                 NaN
# 16                                                                                                                 NaN
# 21                                                                                                                 NaN
# 34                                                                                                                 NaN
# 37                                                                                                                 NaN
# 78                                                                                                                 NaN
# 93                                                                                                                 NaN
# 125                                                                                                                NaN
# 343                                                                                                                NaN
# 406                                                                                                                NaN
# 450                                                                                                                NaN
# 622                                                                                                                NaN
# 661                                                                                                                NaN
# 704                                                                                                                NaN
# 960                                                                                                                NaN
# 961                                                                                                                NaN
# 996                                                                                                                NaN
# 1009                                                                                                               NaN
# 1134                                                                                                               NaN
# 1563                                                                                                      Sasoon House
# 2127  TRIDENT CORPORATE SERVICES (BAHAMAS), LIMITED, PROVIDENCE HOUSE, EAST HILL ST. P.O. BOX N-3944, NASSAU, BAHAMAS.
# 2161                                                        ST. ANDREW'S COURT FREDERICK STREET, STEPS, NASSAU BAHAMAS
#
#      countries country_codes                                       sourceID  \
# 12     Bahamas           BHS                                  Bahamas Leaks
# 16     Bahamas           BHS                                  Bahamas Leaks
# 21     Bahamas           BHS                                  Bahamas Leaks
# 34     Bahamas           BHS                                  Bahamas Leaks
# 37     Bahamas           BHS                                  Bahamas Leaks
# 78     Bahamas           BHS                                  Bahamas Leaks
# 93     Bahamas           BHS                                  Bahamas Leaks
# 125    Bahamas           BHS                                  Bahamas Leaks
# 343    Bahamas           BHS                                  Bahamas Leaks
# 406    Bahamas           BHS                                  Bahamas Leaks
# 450    Bahamas           BHS                                  Bahamas Leaks
# 622    Bahamas           BHS                                  Panama Papers
# 661    Bahamas           BHS                                  Panama Papers
# 704    Bahamas           BHS                                  Panama Papers
# 960    Bahamas           BHS                                  Panama Papers
# 961    Bahamas           BHS                                  Panama Papers
# 996    Bahamas           BHS                                  Panama Papers
# 1009   Bahamas           BHS                                  Panama Papers
# 1134   Bahamas           BHS                                  Panama Papers
# 1563   Bahamas           BHS                      Paradise Papers - Appleby
# 2127   Bahamas           BHS  Paradise Papers - Barbados corporate registry
# 2161   Bahamas           BHS  Paradise Papers - Barbados corporate registry
#
#                                                    valid_until note  \
# 12       The Bahamas Leaks data is current through early 2016.  NaN
# 16       The Bahamas Leaks data is current through early 2016.  NaN
# 21       The Bahamas Leaks data is current through early 2016.  NaN
# 34       The Bahamas Leaks data is current through early 2016.  NaN
# 37       The Bahamas Leaks data is current through early 2016.  NaN
# 78       The Bahamas Leaks data is current through early 2016.  NaN
# 93       The Bahamas Leaks data is current through early 2016.  NaN
# 125      The Bahamas Leaks data is current through early 2016.  NaN
# 343      The Bahamas Leaks data is current through early 2016.  NaN
# 406      The Bahamas Leaks data is current through early 2016.  NaN
# 450      The Bahamas Leaks data is current through early 2016.  NaN
# 622            The Panama Papers  data is current through 2015  NaN
# 661            The Panama Papers  data is current through 2015  NaN
# 704            The Panama Papers  data is current through 2015  NaN
# 960            The Panama Papers  data is current through 2015  NaN
# 961            The Panama Papers  data is current through 2015  NaN
# 996            The Panama Papers  data is current through 2015  NaN
# 1009           The Panama Papers  data is current through 2015  NaN
# 1134           The Panama Papers  data is current through 2015  NaN
# 1563                      Appleby data is current through 2014  NaN
# 2127  Barbados corporate registry data is current through 2016  NaN
# 2161  Barbados corporate registry data is current through 2016  NaN
#
#                                                                                                                                      working_address  \
# 12                                                                                     #308 EAST BAY ST. 4TH FLOOR, P.O. BOX N-7768, NASSAU, BAHAMAS
# 16                                                                       SASSOON HOUSE SHIRLEY ST. & VICTORIA AVE, P.O. BOX SS-5383, NASSAU, BAHAMAS
# 21                                                                       3RD FLOOR, ONE MONTAGUE PLACE, EAST BAY ST. P.O. BOX N3231, NASSAU, BAHAMAS
# 34                                                                        31B, ANNEX BUILDING EAST BAY ST. 2ND FL., P.O. BOX N-3930, NASSAU, BAHAMAS
# 37                                                       SUITE #102 SAFFREY SQUARE 1ST FLOOR, P.O. BOX CB-13937 BAY ST. & BANK LANE, NASSAU, BAHAMAS
# 78                                                                              #10 PETRONA HOUSE, FOWLER ST. EAST, P.O. BOX N 1375, NASSAU, BAHAMAS
# 93                                                                                        308 EAST BAY ST. 3RD FL., P.O. BOX N-7527, NASSAU, BAHAMAS
# 125                                                                        3RD FLOOR, MARITIME HOUSE, FREDERICK ST. P.O. BOX N-4584, NASSAU, BAHAMAS
# 343                                                                                 DOWDESWELL ST. KI-MALEX HOUSE, P.O. BOX SS-6836, NASSAU, BAHAMAS
# 406                                                                               MALBOROUGH ST. & NAVY LION RD., P.O. BOX SS-19051, NASSAU, BAHAMAS
# 450                                                                      ST. MALCOLM BUILDING, VICTORIA & BAY STS, P.O. BOX SS-6738, NASSAU, BAHAMAS
# 622   BAHAMAS FINANCIAL CENTRE; SHIRLEY 7 CHARLOTTE STREET; FOURTH FLOOR; NASSAU BAHAMAS FINANCIAL CENTRE; SHIRLEY 7 CHARLOTTE ST. 4TH FLOOR; NASSAU
# 661                                  c/o GTC Corporate Services Limited; Sassoon House; Shirley St. & Victoria Ave.; PO Box SS-5383; Nassau; Bahamas
# 704                                                                                    Conchrest 6 A West Bay St. P.O. Box CB 10974; Nassau; Bahamas
# 960                                                                                      St. Andrew's Court; Frederick Street Steps; Nassau; Bahamas
# 961                                                                    St. Andrew's Court; Frederick Street Steps; P. O. Box N-4805; Nassau; Bahamas
# 996                                                                      Suite E-2; Union Court Bldg.; Elizabeth Av. and Shirley St.  Nassau Bahamas
# 1009                                                                        Suite E2 Union Court Building Elisabeth Ave. Shirley St. Nassau, Bahamas
# 1134                                                                               UNION COURT BLDG ELISABETH AVE AND SHIRLEY ST. NASSAU THE BAHAMAS
# 1563                                                        Sasoon House; Shirley St. & Victoria Ave.; PO Box N-272; Nassau; New Providence; Bahamas
# 2127                                TRIDENT CORPORATE SERVICES (BAHAMAS), LIMITED, PROVIDENCE HOUSE, EAST HILL ST. P.O. BOX N-3944, NASSAU, BAHAMAS.
# 2161                                                                                      ST. ANDREW'S COURT FREDERICK STREET, STEPS, NASSAU BAHAMAS
#
#                                                                                                                                                          address_wordlist
# 12                                                                                              [#308, east, bay, st., 4th, floor,, p.o., box, n-7768,, nassau,, bahamas]
# 16                                                                               [sassoon, house, shirley, st., &, victoria, ave,, p.o., box, ss-5383,, nassau,, bahamas]
# 21                                                                              [3rd, floor,, one, montague, place,, east, bay, st., p.o., box, n3231,, nassau,, bahamas]
# 34                                                                               [31b,, annex, building, east, bay, st., 2nd, fl.,, p.o., box, n-3930,, nassau,, bahamas]
# 37                                                           [suite, #102, saffrey, square, 1st, floor,, p.o., box, cb-13937, bay, st., &, bank, lane,, nassau,, bahamas]
# 78                                                                                      [#10, petrona, house,, fowler, st., east,, p.o., box, n, 1375,, nassau,, bahamas]
# 93                                                                                                 [308, east, bay, st., 3rd, fl.,, p.o., box, n-7527,, nassau,, bahamas]
# 125                                                                                 [3rd, floor,, maritime, house,, frederick, st., p.o., box, n-4584,, nassau,, bahamas]
# 343                                                                                            [dowdeswell, st., ki-malex, house,, p.o., box, ss-6836,, nassau,, bahamas]
# 406                                                                                        [malborough, st., &, navy, lion, rd.,, p.o., box, ss-19051,, nassau,, bahamas]
# 450                                                                              [st., malcolm, building,, victoria, &, bay, sts,, p.o., box, ss-6738,, nassau,, bahamas]
# 622   [bahamas, financial, centre;, shirley, 7, charlotte, street;, fourth, floor;, nassau, bahamas, financial, centre;, shirley, 7, charlotte, st., 4th, floor;, nassau]
# 661                                     [c/o, gtc, corporate, services, limited;, sassoon, house;, shirley, st., &, victoria, ave.;, po, box, ss-5383;, nassau;, bahamas]
# 704                                                                                            [conchrest, 6, a, west, bay, st., p.o., box, cb, 10974;, nassau;, bahamas]
# 960                                                                                                  [st., andrew's, court;, frederick, street, steps;, nassau;, bahamas]
# 961                                                                            [st., andrew's, court;, frederick, street, steps;, p., o., box, n-4805;, nassau;, bahamas]
# 996                                                                               [suite, e-2;, union, court, bldg.;, elizabeth, av., and, shirley, st., nassau, bahamas]
# 1009                                                                                 [suite, e2, union, court, building, elisabeth, ave., shirley, st., nassau,, bahamas]
# 1134                                                                                        [union, court, bldg, elisabeth, ave, and, shirley, st., nassau, the, bahamas]
# 1563                                                              [sasoon, house;, shirley, st., &, victoria, ave.;, po, box, n-272;, nassau;, new, providence;, bahamas]
# 2127                                     [trident, corporate, services, (bahamas),, limited,, providence, house,, east, hill, st., p.o., box, n-3944,, nassau,, bahamas.]
# 2161                                                                                                  [st., andrew's, court, frederick, street,, steps,, nassau, bahamas]

# %% [markdown]
# ## Standardize values
#
# After some trial and error, I settled on the following standardizations to start:
#
# - Lowercase everything
# - Replace "&" with "and"
# - Remove punctuation
# - Expand abbreviations

# %% [markdown]
# ### Lowercase everything
#
# Different capitalization strategies quickly complicate an analysis as most value matching is based on exact matches.

# %%
df['working_address'] = df['address'].str.lower()

# %% [markdown]
# ### Replace "&"
#
# In the Bahamas addresses "&" and "and" are used interchangeably.
#
# I did a quick sanity check to ensure that "&" wasn't being used in another way. There are only 326 rows that use "&". A quick perusal shows that most, if not all, are used to connect street names.

# %%
df['working_address'] = df['working_address'].str.replace('&', 'and')

# %% [markdown]
# ### Remove punctuation
#
# Punctuation can be particularly helpful in splitting fomratted text blocks into smaller pieces. However, there is no standardized format for these addresses, thus the punctuation actually makes pulling out relevant information and standardizing values harder. For example "-" is generally used in PO Box addresses, but it separates city and country in one row.
#
# After some trial and error, the best process appears to be to replace "-" in all rows with a PO Box with an empty string, the characters \.|,|- as well as newlines with a space, and finally everything else with an empty string (i.e. delete them).

# %%
df.loc[df['working_address'
         ].str.contains('box\s?\w+-\d+'), 'working_address'
      ]  = df.loc[df['working_address'].str.contains('box\s?\w+-\d+'), 'working_address'].str.replace('-', '')
df['working_address'] = df['working_address'].str.replace('\.|,|-', ' ', regex=True)

newline_list = '\t\r\n'
remove_newline = str.maketrans(' ', ' ', newline_list)
punct_list = string.punctuation + '—¿–'
nopunct = str.maketrans('', '', punct_list)

df['working_address'] = df['working_address'].str.translate(remove_newline).str.translate(nopunct)
df['working_address']
# Out:
# 0                                                                               annex frederick and shirley sts  p o  box n4805  nassau  bahamas
# 1                                                                                 suite e2 union court building  p o  box n8188  nassau  bahamas
# 2                                                                                  lyford cay house  lyford cay  p o  box n7785  nassau  bahamas
# 3                                             p o  box n3708 bahamas financial centre  p o  box n3708 shirley and charlotte sts  nassau  bahamas
# 4                                                                       lyford cay house  3rd floor  lyford cay  p o  box n3024  nassau  bahamas
#                                                                           ...
# 2253                                                                       j p morgan trust company bahamas limited  nassau  n 4899  zh  bahamas
# 2254                                                                 montagne sterline centre  east bav street  nassau  country bahamas  bahamas
# 2255                                                                                     deltec house  lyford cay  po box n3229  nassau  bahamas
# 2256                                                   providence house  hast wing  east hill street  p o  box cb12399  nassau  cb12399  bahamas
# 2257    coj p  morgan trust company bahamas limited  bahamas financial center 2ntl floor  shirley and charlotte streets  nassau  n 4899  bahamas
# Name: working_address, Length: 2258, dtype: object

# %% [markdown]
# ### Standardize abbreviations
#
# I got the majority of the abbreviations the hard way, I went though the dataset by hand. I was attempting to pull out the city name for each address that had a street in it. The only way to do this for many addresses was to look at the street, resulting in a lot of `contains` searches.
#
# In the frequency count I also noticed that "p" and "o" occur rather frequently. A quick peek shows that in 84 rows "po box" is listed as "p o box". When doing replacements like these, it's important to do sanity checks as the results won't always be what you expect. One of my favorite examples was a search for "demon", I also got "demonstrate". Watch out for these kinds of things. Fortunately, in the "po box" example for the Bahamas addresses "p o" only occurs when for PO boxes.
#
# There are also occurences of "pobox", but in joining "p" and "o" from "p o" gives me one last "pobox" so I'll need to apply this after the main abbreviation changes.

# %% [markdown]
# #### The difficulties of "street"
#
# Replacing "st" was particularly challenging. Simply replacing "st" with "street" will also alter the following words:
#
# - street: streetreet
# - sts: streets
# - west: westreet
# - east: eastreet
# - st: street
# - first: firstreet
# - trust: trustreet
#
# I only discovered this after applying several iterations of "st" replacements and re-running word counts. I ended up looking for " st " esentially ensuring there was a space before and after "st". This also had the side effect of ensuring the "saint" rows remain the same.
#
# I also made the mistake of replacing " st " with "street" essentially connecting it with the words around it. I got a lot of "unionstreet" and "streetnassau" values. Fortunately, the solution is simple, just add the spaces back in.

# %%
abbrev_dict = {'\sst\s': ' street ',
              'str\s': 'street ',
              'streets': 'street',
              'sts': 'street',
              'blvd': 'boulevard',
              'sq\s': 'square ',
              'dr\s': 'drive ',
              'ave\s': 'avenue ',
              '\sln': ' lane',
              'lanes': 'lane',
              'hwy': 'highway',
              '1st': 'first',
              '2nd': 'second',
              '2 nd': 'second',
              '3rd': 'third',
              '4th': 'fourth',
              '5th': 'fifth',
              '6th': 'sixth',
              '7th': 'seventh',
              '8th': 'eighth',
              '9th': 'ninth',
              'p o': 'po',
              'pobox': 'po box',
               '\s\s+': ' ',
               'nassaubahamas':'nassau bahamas'}

# %%
df['working_address'] = df['working_address'].replace(abbrev_dict, regex=True)

# %%
df.loc[df['working_address'
         ].str.contains('street\w+'), 'working_address'
      ] = df.loc[df['working_address'].str.contains('street\w+'), 'working_address'].str.replace('street', 'street ')

df.loc[df['working_address'
         ].str.contains('\w+street'), 'working_address'
      ] = df.loc[df['working_address'].str.contains('\w+street'), 'working_address'].str.replace('street', ' street')

# %% [markdown]
# ## Random extras

# %%
df[df['working_address'].str.contains("343nass")]
# Out:
#       node_id                   address name countries country_codes  \
# 681  14035227  CB 11.343/Nassau Bahamas  NaN   Bahamas           BHS
#
#           sourceID                                      valid_until note  \
# 681  Panama Papers  The Panama Papers  data is current through 2015  NaN
#
#              working_address              address_wordlist
# 681  cb 11 343nassau bahamas  [cb, 11.343/nassau, bahamas]

# %%
df.loc[df['working_address'].str.contains("343nass"), 'working_address'] = 'cb 11 343 nassau bahamas'

# %%
df[df['working_address'].str.contains("343nass")]
# Out:
# Empty DataFrame
# Columns: [node_id, address, name, countries, country_codes, sourceID, valid_until, note, working_address, address_wordlist]
# Index: []

# %%
df[df['working_address'].str.contains(" 343 nass")]
# Out:
#         node_id  \
# 577    14026445
# 578    14026446
# 655    14031493
# 656    14031494
# 657    14031495
# 658    14031496
# 681    14035227
# 683    14035229
# 2208  240450064
#
#                                                                                                                        address  \
# 577   ALEMAN; CORDERO; GALINDO & LEE (BAHAMAS) LIMITED; BOLAM HOUSE; KING & GEORGES STREETS; PO BOX CB 11.343; NASSAU; BAHAMAS
# 578    Aleman; Cordero; Galindo & Lee (Bahamas) Limited; Bolam House; King & George Streets; PO Box CB 11.343; Nassau; Bahamas
# 655                                                         BOLAM HOUSE KING & GEORGE STREETS P O BOX CB 11.343 NASSAU BAHAMAS
# 656                                                      Bolam House; King & George Streets; PO BOX CB 11-343; NASSAU; BAHAMAS
# 657                                                     Bolam House; King and George Street; P.O. Box 11; 343; Nassau; Bahamas
# 658                                                   Bolam House; King and George Streets. P.O. Box CB 11.343 Nassau; Bahamas
# 681                                                                                                   CB 11.343/Nassau Bahamas
# 683                                                                                                  CB11.343; Nassau; Bahamas
# 2208                                      WINTERBOTHAM PLACE, MARLBOROUGH & QUEEN STREETS, P.O. BOX CB 11.343, NASSAU, BAHAMAS
#
#      name countries country_codes                                 sourceID  \
# 577   NaN   Bahamas           BHS                            Panama Papers
# 578   NaN   Bahamas           BHS                            Panama Papers
# 655   NaN   Bahamas           BHS                            Panama Papers
# 656   NaN   Bahamas           BHS                            Panama Papers
# 657   NaN   Bahamas           BHS                            Panama Papers
# 658   NaN   Bahamas           BHS                            Panama Papers
# 681   NaN   Bahamas           BHS                            Panama Papers
# 683   NaN   Bahamas           BHS                            Panama Papers
# 2208  NaN   Bahamas           BHS  Pandora Papers - SFM Corporate Services
#
#                                           valid_until note  \
# 577   The Panama Papers  data is current through 2015  NaN
# 578   The Panama Papers  data is current through 2015  NaN
# 655   The Panama Papers  data is current through 2015  NaN
# 656   The Panama Papers  data is current through 2015  NaN
# 657   The Panama Papers  data is current through 2015  NaN
# 658   The Panama Papers  data is current through 2015  NaN
# 681   The Panama Papers  data is current through 2015  NaN
# 683   The Panama Papers  data is current through 2015  NaN
# 2208            Provider data is current through 2015  NaN
#
#                                                                                                          working_address  \
# 577   aleman cordero galindo and lee bahamas limited bolam house king and georges street po box cb 11 343 nassau bahamas
# 578    aleman cordero galindo and lee bahamas limited bolam house king and george street po box cb 11 343 nassau bahamas
# 655                                                   bolam house king and george street po box cb 11 343 nassau bahamas
# 656                                                   bolam house king and george street po box cb 11 343 nassau bahamas
# 657                                                      bolam house king and george street po box 11 343 nassau bahamas
# 658                                                   bolam house king and george street po box cb 11 343 nassau bahamas
# 681                                                                                             cb 11 343 nassau bahamas
# 683                                                                                              cb11 343 nassau bahamas
# 2208                                     winterbotham place marlborough and queen street po box cb 11 343 nassau bahamas
#
#                                                                                                                                   address_wordlist
# 577   [aleman;, cordero;, galindo, &, lee, (bahamas), limited;, bolam, house;, king, &, georges, streets;, po, box, cb, 11.343;, nassau;, bahamas]
# 578    [aleman;, cordero;, galindo, &, lee, (bahamas), limited;, bolam, house;, king, &, george, streets;, po, box, cb, 11.343;, nassau;, bahamas]
# 655                                                               [bolam, house, king, &, george, streets, p, o, box, cb, 11.343, nassau, bahamas]
# 656                                                             [bolam, house;, king, &, george, streets;, po, box, cb, 11-343;, nassau;, bahamas]
# 657                                                            [bolam, house;, king, and, george, street;, p.o., box, 11;, 343;, nassau;, bahamas]
# 658                                                          [bolam, house;, king, and, george, streets., p.o., box, cb, 11.343, nassau;, bahamas]
# 681                                                                                                                   [cb, 11.343/nassau, bahamas]
# 683                                                                                                                  [cb11.343;, nassau;, bahamas]
# 2208                                             [winterbotham, place,, marlborough, &, queen, streets,, p.o., box, cb, 11.343,, nassau,, bahamas]

# %% [markdown]
# ## Save to csv

# %%
df.drop('address_wordlist', axis=1).to_csv('data/parsed_bahamas_addresses.csv', index=False)
